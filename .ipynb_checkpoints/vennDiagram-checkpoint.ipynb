# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
import pandas as pd

# Define the set labels
labels = {
    '100': 'Cybersecurity\n(C)',
    '010': 'Artificial Intelligence\n(AI)',
    '001': 'Machine Learning\n(ML)',
    '110': '',  # Intersection of C and AI
    '101': '',  # Intersection of C and ML
    '011': '',  # Intersection of AI and ML
    '111': '',  # All three (not used here)
}

# Create the Venn diagram
plt.figure(figsize=(8, 6))
venn = venn3(subsets=(1, 1, 1, 0, 0, 1, 0), set_labels=('Cybersecurity (C)', 'AI', 'ML'))
for subset in labels:
    if labels[subset]:
        venn.get_label_by_id(subset).set_text(labels[subset])

plt.title("Venn Diagram of Computer Science Domains")
fig.savefig('Venn Diagram of Computer Science Domains.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 23
#      20         venn.get_label_by_id(subset).set_text(labels[subset])
#      22 plt.title("Venn Diagram of Computer Science Domains")
# ---> 23 fig.savefig('Venn Diagram of Computer Science Domains.png')
#      24 plt.show()
#
# NameError: name 'fig' is not defined
