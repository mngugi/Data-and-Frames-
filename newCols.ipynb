# %%
import pandas as pd 
df = pd.read_csv('trainTruFalse.csv')
df
# Out:
#                id        label  \
# 0       2635.json        false
# 1        324.json  mostly-true
# 2       1123.json        false
# 3      12465.json         true
# 4        153.json    half-true
# ...           ...          ...
# 10042   4388.json   pants-fire
# 10043   1592.json    half-true
# 10044   5473.json  mostly-true
# 10045   3408.json  mostly-true
# 10046   1155.json   pants-fire
#
#                                                statement  \
# 0      Says the Annies List political group supports ...
# 1      Hillary Clinton agrees with John McCain "by vo...
# 2      Health care reform legislation is likely to ma...
# 3      The Chicago Bears have had more starting quart...
# 4      "I'm the only person on this stage who has wor...
# ...                                                  ...
# 10042  Mayor Fung wants to punish our childrens educa...
# 10043  "Under the ruling of the Supreme Court, any lo...
# 10044  There are a larger number of shark attacks in ...
# ...
